# %% [markdown]
# # Circular Doubly Linked List

# %% [markdown]
# ### 1. Define a class Node to describe a node of a circular doubly linked list.

# %%
class Node: 
    def __init__(self,item,prev=None,next=None):
        self.prev=prev
        self.item=item
        self.next=next

# %% [markdown]
# ### 2. Define a class CDLL to implement Circular Doubly Linked List with __init__() method to create and initalise last reference variable

# %%
class CDLL:
    def __init__(self):
        self.start=None

# %% [markdown]
# ### 3. Define a method is_empty() to check if the linked list is empty in CDLL class.

# %%
class CDLL:
    def __init__(self):
        self.start=None
    
    def is_empty(self):
        return self.start==None
l=CDLL()
print(l.is_empty())
l.start=Node(1)
print(l.is_empty())
# Out:
# True
# False

# %% [markdown]
# ### 4. In class CDLL, define a method insert_at_start() to insert an element at the starting of the list.

# %%
class CDLL:
    def __init__(self):
        self.start=None
    
    def is_empty(self):
        return self.start==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            new_node.prev=new_node
            self.start=new_node
        else:
            new_node.next=self.start
            new_node.prev=self.start.prev
            self.start.prev.next=new_node
            self.start.prev=new_node
            self.start=new_node
    
    
l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_start(1)
# Out:
# True
# True

# %% [markdown]
# ### 5. In class CDLL, define a method insert_at_last() to insert an element at the end of the list

# %%
class CDLL:
    def __init__(self):
        self.start=None
    
    def is_empty(self):
        return self.start==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            new_node.prev=new_node
            self.start=new_node
        else:
            new_node.next=self.start
            new_node.prev=self.start.prev
            self.start.prev.next=new_node
            self.start.prev=new_node
            self.start=new_node
    
    def insert_at_last(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node
    
    
l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_start(1)
l.insert_at_last(2)
# Out:
# True
# True

# %% [markdown]
# ### 6. In class CDLL, define a method search() to find the node with specified element

# %%
class CDLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start == None

    def insert_at_start(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node
            self.start = new_node

    def insert_at_last(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node

    def search(self, element):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        
        temp = self.start
        index = 1

        while True:
            if temp.item == element:
                return f"The element is at node {index}"

            temp = temp.next
            index += 1

            if temp == self.start:
                break 
        return f"The element {element} doesn't exist in the Linked List"

    
    
l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_start(1)
l.insert_at_start(2)
l.insert_at_start(3)
l.insert_at_last(4)
l.search(4)
# Out:
# True
# True
# 'The element is at node 4'

# %% [markdown]
# ### 7. In class CDLL, define a method insert_after() to insert a new node after a given node of the list.

# %%
class CDLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start == None

    def insert_at_start(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node
            self.start = new_node

    def insert_at_last(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node

            
            
    def insert_after(self,element,data):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        new_node=Node(data)
        temp=self.start
        while True:
            if temp.item==element:
                new_node.prev=temp
                new_node.next=temp.next
                temp.next=new_node
                break
            temp=temp.next
            if temp==self.start:
                break
            return f"The element {element} doesn't exist in the Linked List"
        
        
    def search(self, element):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        temp = self.start
        index = 1
        while True:
            if temp.item == element:
                return f"The element is at node {index}"
            temp = temp.next
            index += 1
            if temp == self.start:
                break 
        return f"The element {element} doesn't exist in the Linked List"

    
    
l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_last(1)
l.insert_at_last(3)
l.insert_at_last(4)
l.insert_after(1,2)
l.search(2)
# Out:
# True
# True
# 'The element is at node 2'

# %% [markdown]
# ### 8. In class CDLL, define a method to print all the element of the list.

# %%
class CDLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start == None

    def insert_at_start(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node
            self.start = new_node

    def insert_at_last(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node

            
            
    def insert_after(self,element,data):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        new_node=Node(data)
        temp=self.start
        while True:
            if temp.item==element:
                new_node.prev=temp
                new_node.next=temp.next
                temp.next=new_node
                break
            temp=temp.next
            if temp==self.start:
                break
            return f"The element {element} doesn't exist in the Linked List"
        
        
    def search(self, element):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        temp = self.start
        index = 1
        while True:
            if temp.item == element:
                return f"The element is at node {index}"
            temp = temp.next
            index += 1
            if temp == self.start:
                break 
        return f"The element {element} doesn't exist in the Linked List"
    
    def __str__(self):
        if self.is_empty():
            return '[]'
        res=[]
        temp=self.start
        while True:
            res.append(str(temp.item))
            temp=temp.next
            if temp==self.start:
                break
        return ','.join(res)

    
    
l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_last(1)
l.insert_at_last(3)
l.insert_at_last(4)
l.insert_after(1,2)
l.search(2)   
print(l)
# Out:
# True
# True
# 1,2,3,4

# %% [markdown]
# ### 9. In class CDLL, implement iterator for CDLL to access all the elements of the list in a sequence.

# %%
class CDLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start == None

    def insert_at_start(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node
            self.start = new_node

    def insert_at_last(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node

            
            
    def insert_after(self,element,data):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        new_node=Node(data)
        temp=self.start
        while True:
            if temp.item==element:
                new_node.prev=temp
                new_node.next=temp.next
                temp.next=new_node
                break
            temp=temp.next
            if temp==self.start:
                break
            return f"The element {element} doesn't exist in the Linked List"
        
        
    def search(self, element):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        temp = self.start
        index = 1
        while True:
            if temp.item == element:
                return f"The element is at node {index}"
            temp = temp.next
            index += 1
            if temp == self.start:
                break 
        return f"The element {element} doesn't exist in the Linked List"
    
    def __str__(self):
        if self.is_empty():
            return '[]'
        res=[]
        temp=self.start
        while True:
            res.append(str(temp.item))
            temp=temp.next
            if temp==self.start:
                break
        return ','.join(res)
    
    def __iter__(self):
        if self.is_empty():
            raise StopIteration("There is no element in the Linked List.")
        self.current = self.start
        return self

    def __next__(self):
        if self.is_empty() or (self.current is None and self.current == self.start):
            raise StopIteration
        else:
            if self.current:
                data = self.current.item
                self.current = self.current.next
                if self.current == self.start:
                    self.current = None  # Reset to None at the end
                return data
            else:
                raise StopIteration


    
    
l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_last(1)
l.insert_at_last(3)
l.insert_at_last(4)
l.insert_after(1,2)
l.search(2)   
print(l)
for i in l:
    print(i)
# Out:
# True
# True
# 1,2,3,4
# 1
# 2
# 3
# 4

# %% [markdown]
# ### 10. In class CDLL, define a method delete_first() to delete first element from the list.

# %%
class CDLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start == None

    def insert_at_start(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node
            self.start = new_node

    def insert_at_last(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node

            
            
    def insert_after(self,element,data):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        new_node=Node(data)
        temp=self.start
        while True:
            if temp.item==element:
                new_node.prev=temp
                new_node.next=temp.next
                temp.next=new_node
                break
            temp=temp.next
            if temp==self.start:
                break
            return f"The element {element} doesn't exist in the Linked List"
        
        
    def search(self, element):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        temp = self.start
        index = 1
        while True:
            if temp.item == element:
                return f"The element is at node {index}"
            temp = temp.next
            index += 1
            if temp == self.start:
                break 
        return f"The element {element} doesn't exist in the Linked List"
    
    def __str__(self):
        if self.is_empty():
            return '[]'
        res=[]
        temp=self.start
        while True:
            res.append(str(temp.item))
            temp=temp.next
            if temp==self.start:
                break
        return ','.join(res)
    
    def __iter__(self):
        if self.is_empty():
            raise StopIteration("There is no element in the Linked List.")
        self.current = self.start
        return self

    def __next__(self):
        if self.is_empty() or (self.current is None and self.current == self.start):
            raise StopIteration
        else:
            if self.current:
                data = self.current.item
                self.current = self.current.next
                if self.current == self.start:
                    self.current = None  # Reset to None at the end
                return data
            else:
                raise StopIteration

    
    def delete_first(self):
        if self.is_empty():
            return None
        elif self.start.next==self.start:
            self.start=None
        else:
            self.start.prev.next=self.start.next
            self.start.next.prev=self.start.prev
            self.start=self.start.next
    
    
l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_last(1)
l.insert_at_last(3)
l.insert_at_last(4)
l.insert_after(1,2)
l.search(2)   
print(l)
for i in l:
    print(i)
l.delete_first()   
print(l)
# Out:
# True
# True
# 1,2,3,4
# 1
# 2
# 3
# 4
# 2,3,4

# %% [markdown]
# ### 11. In class CDLL, define a method delete_last() to delete last element from the list.

# %%
class CDLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start == None

    def insert_at_start(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node
            self.start = new_node

    def insert_at_last(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node

            
            
    def insert_after(self,element,data):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        new_node=Node(data)
        temp=self.start
        while True:
            if temp.item==element:
                new_node.prev=temp
                new_node.next=temp.next
                temp.next=new_node
                break
            temp=temp.next
            if temp==self.start:
                break
            return f"The element {element} doesn't exist in the Linked List"
        
        
    def search(self, element):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        temp = self.start
        index = 1
        while True:
            if temp.item == element:
                return f"The element is at node {index}"
            temp = temp.next
            index += 1
            if temp == self.start:
                break 
        return f"The element {element} doesn't exist in the Linked List"
    
    def __str__(self):
        if self.is_empty():
            return '[]'
        res=[]
        temp=self.start
        while True:
            res.append(str(temp.item))
            temp=temp.next
            if temp==self.start:
                break
        return ','.join(res)
    
    def __iter__(self):
        if self.is_empty():
            raise StopIteration("There is no element in the Linked List.")
        self.current = self.start
        return self

    def __next__(self):
        if self.is_empty() or (self.current is None and self.current == self.start):
            raise StopIteration
        else:
            if self.current:
                data = self.current.item
                self.current = self.current.next
                if self.current == self.start:
                    self.current = None  # Reset to None at the end
                return data
            else:
                raise StopIteration

    
    def delete_first(self):
        if self.is_empty():
            return None
        elif self.start.next==self.start:
            self.start=None
        else:
            self.start.prev.next=self.start.next
            self.start.next.prev=self.start.prev
            self.start=self.start.next
    
    def delete_last(self):
        if self.is_empty():
            return None
        elif self.start.next==self.start:
            self.start=None
        else:
            self.start.prev.prev.next=self.start
            self.start.prev=self.start.prev.prev
    
    
l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_last(1)
l.insert_at_last(3)
l.insert_at_last(4)
l.insert_after(1,2)
l.search(2)   
print(l)
for i in l:
    print(i)
l.delete_first()   
print(l)
l.delete_last()
print(l)
# Out:
# True
# True
# 1,2,3,4
# 1
# 2
# 3
# 4
# 2,3,4
# 2,3

# %% [markdown]
# ### 12. In class CDLL, define a method delete_item() to delete specified element from the list.

# %%
class CDLL:
    def __init__(self):
        self.start = None

    def is_empty(self):
        return self.start == None

    def insert_at_start(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node
            self.start = new_node

    def insert_at_last(self, data):
        new_node = Node(data)
        if self.is_empty():
            new_node.next = new_node
            new_node.prev = new_node
            self.start = new_node
        else:
            new_node.next = self.start
            new_node.prev = self.start.prev
            self.start.prev.next = new_node
            self.start.prev = new_node

            
            
    def insert_after(self,element,data):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        new_node=Node(data)
        temp=self.start
        while True:
            if temp.item==element:
                new_node.prev=temp
                new_node.next=temp.next
                temp.next=new_node
                break
            temp=temp.next
            if temp==self.start:
                break
            return f"The element {element} doesn't exist in the Linked List"
        
        
    def search(self, element):
        if self.is_empty():
            return f"The element {element} doesn't exist in the Linked List"
        temp = self.start
        index = 1
        while True:
            if temp.item == element:
                return f"The element is at node {index}"
            temp = temp.next
            index += 1
            if temp == self.start:
                break 
        return f"The element {element} doesn't exist in the Linked List"
    
    def __str__(self):
        if self.is_empty():
            return '[]'
        res=[]
        temp=self.start
        while True:
            res.append(str(temp.item))
            temp=temp.next
            if temp==self.start:
                break
        return ','.join(res)
    
    def __iter__(self):
        if self.is_empty():
            raise StopIteration("There is no element in the Linked List.")
        self.current = self.start
        return self

    def __next__(self):
        if self.is_empty() or (self.current is None and self.current == self.start):
            raise StopIteration
        else:
            if self.current:
                data = self.current.item
                self.current = self.current.next
                if self.current == self.start:
                    self.current = None  # Reset to None at the end
                return data
            else:
                raise StopIteration

    
    def delete_first(self):
        if self.is_empty():
            return None
        elif self.start.next==self.start:
            self.start=None
        else:
            self.start.prev.next=self.start.next
            self.start.next.prev=self.start.prev
            self.start=self.start.next
    
    def delete_last(self):
        if self.is_empty():
            return None
        elif self.start.next==self.start:
            self.start=None
        else:
            self.start.prev.prev.next=self.start
            self.start.prev=self.start.prev.prev
    
    def delete_item(self,element):
            if self.is_empty():
                return f"The element {element} already doesn't exist in the Linked List"
            temp=self.start
            if temp.item==element:
                self.delete_first()
            else:
                temp=temp.next
                while temp!=self.start:
                    if temp.item==data:
                        temp.next.prev=temp.prev
                        temp.prev.next=temp.next

l=CDLL()
print(l.is_empty())
print(l.is_empty())
l.insert_at_last(1)
l.insert_at_last(3)
l.insert_at_last(4)
l.insert_after(1,2)
l.search(2)   
print(l)
for i in l:
    print(i)
l.delete_first()   
print(l)
l.delete_last()
print(l)
l.delete_item(2)
print(l)
# Out:
# True
# True
# 1,2,3,4
# 1
# 2
# 3
# 4
# 2,3,4
# 2,3
# 3

# %%
print(l)
# Out:
# 3
