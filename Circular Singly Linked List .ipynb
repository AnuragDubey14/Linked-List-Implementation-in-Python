# %% [markdown]
# # Circular Singly Linked List

# %% [markdown]
# ### 1. define a class Node to describe a node of a circular linked list.

# %%
class Node:
    def __init__(self,data):
        self.next=None
        self.data=data

# %% [markdown]
# ### 2. Define a class CLL to implement Circular Linked List with __init__() method to create and initialise last reference variable.

# %%
class CLL:
    def __init__(self):
        self.last=None

# %% [markdown]
# ### 3. Define a method is_empty() to check if the linked list is empty in CLL class.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
cll1=CLL()
cll1.is_empty()
# Out:
# True

# %% [markdown]
# ### 4. In class CLL, define a method insert_at_start() to insert an element at starting of the list.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)

# %% [markdown]
# ### 5. In class CLL, define a method insert_at_last() to insert an element at the end if the list.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
    def insert_at_last(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            self.last=new_node
            
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)
cll1.insert_at_last(2)

# %% [markdown]
# ### 6. In class CLL, define a method search() to find the node with specified element value.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
    def insert_at_last(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            self.last=new_node
            
    def search(self, data):
        if self.is_empty():
            return 'The Circular Linked List is empty'
        else:
            counter = 0
            temp = self.last.next
            while True:
                if temp.data == data:
                    return f'The element {data} is at node {counter}'
                temp = temp.next
                counter += 1
                if temp == self.last.next:
                    break
            return f"The element {data} doesn't exist in the linked list"

    
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)
cll1.insert_at_last(2)
cll1.search(2)
# Out:
# 'The element 2 is at node 1'

# %% [markdown]
# ### 7. In class define a method insert_after() to insert a new node after a given node of the list.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
    def insert_at_last(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            self.last=new_node
     
    def insert_after(self,element,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            temp=self.last.next
            while True:
                if temp.data==element:
                    new_node.next=temp.next
                    temp.next=new_node
                    break
                if temp==self.last.next:
                    return f"The element {element} doesn't exist in the linked list"
                
    def search(self, data):
        if self.is_empty():
            return 'The Circular Linked List is empty'
        else:
            counter = 0
            temp = self.last.next
            while True:
                if temp.data == data:
                    return f'The element {data} is at node {counter}'
                temp = temp.next
                counter += 1
                if temp == self.last.next:
                    break
            return f"The element {data} doesn't exist in the linked list"

    
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)
cll1.insert_at_last(2)
cll1.search(2)
cll1.insert_after(1,3)
cll1.search(3)
# Out:
# 'The element 3 is at node 1'

# %% [markdown]
# ### 8. In class CLL, define a method to print all the elements of the list.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
    def insert_at_last(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            self.last=new_node
     
    def insert_after(self,element,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            temp=self.last.next
            while True:
                if temp.data==element:
                    new_node.next=temp.next
                    temp.next=new_node
                    break
                if temp==self.last.next:
                    return f"The element {element} doesn't exist in the linked list"
                
    def search(self, data):
        if self.is_empty():
            return 'The Circular Linked List is empty'
        else:
            counter = 0
            temp = self.last.next
            while True:
                if temp.data == data:
                    return f'The element {data} is at node {counter}'
                temp = temp.next
                counter += 1
                if temp == self.last.next:
                    break
            return f"The element {data} doesn't exist in the linked list"
    def __str__(self):
        if self.is_empty():
            return 'The Linked List is Empty'
        else:
            result=[]
            temp=self.last.next
            while True:
                result.append(str(temp.data))
                temp=temp.next
                if temp==self.last.next:
                    break
            return ' ,'.join(result)

    
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)
cll1.insert_at_last(2)
cll1.search(2)
cll1.insert_after(1,3)
cll1.search(3)
print(cll1)
# Out:
# 1 ,3 ,2

# %% [markdown]
# ### 9. In class CLL, implement iterator for CLL to access all the elements of the list in a sequence

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
    def insert_at_last(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            self.last=new_node
     
    def insert_after(self,element,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            temp=self.last.next
            while True:
                if temp.data==element:
                    new_node.next=temp.next
                    temp.next=new_node
                    break
                if temp==self.last.next:
                    return f"The element {element} doesn't exist in the linked list"
                
    def search(self, data):
        if self.is_empty():
            return 'The Circular Linked List is empty'
        else:
            counter = 0
            temp = self.last.next
            while True:
                if temp.data == data:
                    return f'The element {data} is at node {counter}'
                temp = temp.next
                counter += 1
                if temp == self.last.next:
                    break
            return f"The element {data} doesn't exist in the linked list"
    def __str__(self):
        if self.is_empty():
            return 'The Linked List is Empty'
        else:
            result=[]
            temp=self.last.next
            while True:
                result.append(str(temp.data))
                temp=temp.next
                if temp==self.last.next:
                    break
            return ' ,'.join(result)
        
    def __iter__(self):
        if self.is_empty():
            raise StopIteration("There is no element in the Linked List.")
        self.current = self.last.next
        return self

    def __next__(self):
        if self.is_empty() or (self.current is None and self.current == self.last):
            raise StopIteration
        else:
            if self.current:
                data = self.current.data
                self.current = self.current.next
                if self.current == self.last.next:
                    self.current = None  # Reset to None at the end
                return data
            else:
                raise StopIteration

    
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)
cll1.insert_at_last(2)
cll1.search(2)
cll1.insert_after(1,3)
cll1.search(3)
print(cll1)
for i in cll1:
    print(i)
# Out:
# 1 ,3 ,2
# 1
# 3
# 2

# %% [markdown]
# ### 10. In class CLL, define a method delete_first() to delete first element from the list.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
    def insert_at_last(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            self.last=new_node
     
    def insert_after(self,element,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            temp=self.last.next
            while True:
                if temp.data==element:
                    new_node.next=temp.next
                    temp.next=new_node
                    break
                if temp==self.last.next:
                    return f"The element {element} doesn't exist in the linked list"
                
    def search(self, data):
        if self.is_empty():
            return 'The Circular Linked List is empty'
        else:
            counter = 0
            temp = self.last.next
            while True:
                if temp.data == data:
                    return f'The element {data} is at node {counter}'
                temp = temp.next
                counter += 1
                if temp == self.last.next:
                    break
            return f"The element {data} doesn't exist in the linked list"
    def __str__(self):
        if self.is_empty():
            return 'The Linked List is Empty'
        else:
            result=[]
            temp=self.last.next
            while True:
                result.append(str(temp.data))
                temp=temp.next
                if temp==self.last.next:
                    break
            return ' ,'.join(result)
        
    def __iter__(self):
        if self.is_empty():
            raise StopIteration("There is no element in the Linked List.")
        self.current = self.last.next
        return self

    def __next__(self):
        if self.is_empty() or (self.current is None and self.current == self.last):
            raise StopIteration
        else:
            if self.current:
                data = self.current.data
                self.current = self.current.next
                if self.current == self.last.next:
                    self.current = None  # Reset to None at the end
                return data
            else:
                raise StopIteration
    
    def delete_first(self):
        if self.is_empty():
            return 'The Linked List is Empty.'
        if self.last.next==self.last:
            self.last=None
        else:
            self.last.next=self.last.next.next

    
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)
cll1.insert_at_last(2)
cll1.search(2)
cll1.insert_after(1,3)
cll1.search(3)
print(cll1)
for i in cll1:
    print(i)
cll1.delete_first()
print(cll1)
# Out:
# 1 ,3 ,2
# 1
# 3
# 2
# 3 ,2

# %% [markdown]
# ### 11. In class CLL, define a method delete_last() to delete last element from the list.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
    def insert_at_last(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            self.last=new_node
     
    def insert_after(self,element,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            temp=self.last.next
            while True:
                if temp.data==element:
                    new_node.next=temp.next
                    temp.next=new_node
                    break
                if temp==self.last.next:
                    return f"The element {element} doesn't exist in the linked list"
                
    def search(self, data):
        if self.is_empty():
            return 'The Circular Linked List is empty'
        else:
            counter = 0
            temp = self.last.next
            while True:
                if temp.data == data:
                    return f'The element {data} is at node {counter}'
                temp = temp.next
                counter += 1
                if temp == self.last.next:
                    break
            return f"The element {data} doesn't exist in the linked list"
    def __str__(self):
        if self.is_empty():
            return 'The Linked List is Empty'
        else:
            result=[]
            temp=self.last.next
            while True:
                result.append(str(temp.data))
                temp=temp.next
                if temp==self.last.next:
                    break
            return ' ,'.join(result)
        
    def __iter__(self):
        if self.is_empty():
            raise StopIteration("There is no element in the Linked List.")
        self.current = self.last.next
        return self

    def __next__(self):
        if self.is_empty() or (self.current is None and self.current == self.last):
            raise StopIteration
        else:
            if self.current:
                data = self.current.data
                self.current = self.current.next
                if self.current == self.last.next:
                    self.current = None  # Reset to None at the end
                return data
            else:
                raise StopIteration
    
    def delete_first(self):
        if self.is_empty():
            return 'The Linked List is Empty.'
        if self.last.next==self.last:
            self.last=None
        else:
            self.last.next=self.last.next.next
            
    def delete_last(self):
        if self.is_empty():
            return 'The Linked List is Empty.'
        if self.last.next==self.last:
            self.last=None 
        else:
            temp = self.last.next
            while temp.next != self.last:
                temp = temp.next
            temp.next = self.last.next  # Update the next of the second-to-last node
            self.last = temp  # Update the last node


    
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)
cll1.insert_at_last(2)
cll1.search(2)
cll1.insert_after(1,3)
cll1.search(3)
print(cll1)
for i in cll1:
    print(i)
cll1.delete_first()
print(cll1)
cll1.delete_last()
print(cll1)
# Out:
# 1 ,3 ,2
# 1
# 3
# 2
# 3 ,2
# 3

# %% [markdown]
# ### 12. In class CLL, define a method delete_item() to delete specified element from the list.

# %%
class CLL:
    def __init__(self):
        self.last=None
    
    def is_empty(self):
        return self.last==None
    
    def insert_at_start(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            
    def insert_at_last(self,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            new_node.next=self.last.next
            self.last.next=new_node
            self.last=new_node
     
    def insert_after(self,element,data):
        new_node=Node(data)
        if self.is_empty():
            new_node.next=new_node
            self.last=new_node
        else:
            temp=self.last.next
            while True:
                if temp.data==element:
                    new_node.next=temp.next
                    temp.next=new_node
                    break
                if temp==self.last.next:
                    return f"The element {element} doesn't exist in the linked list"
                
    def search(self, data):
        if self.is_empty():
            return 'The Circular Linked List is empty'
        else:
            counter = 0
            temp = self.last.next
            while True:
                if temp.data == data:
                    return f'The element {data} is at node {counter}'
                temp = temp.next
                counter += 1
                if temp == self.last.next:
                    break
            return f"The element {data} doesn't exist in the linked list"
    def __str__(self):
        if self.is_empty():
            return 'The Linked List is Empty'
        else:
            result=[]
            temp=self.last.next
            while True:
                result.append(str(temp.data))
                temp=temp.next
                if temp==self.last.next:
                    break
            return ' ,'.join(result)
        
    def __iter__(self):
        if self.is_empty():
            raise StopIteration("There is no element in the Linked List.")
        self.current = self.last.next
        return self

    def __next__(self):
        if self.is_empty() or (self.current is None and self.current == self.last):
            raise StopIteration
        else:
            if self.current:
                data = self.current.data
                self.current = self.current.next
                if self.current == self.last.next:
                    self.current = None  # Reset to None at the end
                return data
            else:
                raise StopIteration
    
    def delete_first(self):
        if self.is_empty():
            return 'The Linked List is Empty.'
        if self.last.next==self.last:
            self.last=None
        else:
            self.last.next=self.last.next.next
    
    def delete_last(self):
        if self.is_empty():
            return 'The Linked List is Empty.'
        if self.last.next==self.last:
            self.last=None 
        else:
            temp = self.last.next
            while temp.next != self.last:
                temp = temp.next
            temp.next = self.last.next  # Update the next of the second-to-last node
            self.last = temp  # Update the last node

                
                
    def delete_item(self, data):
        if self.is_empty():
            return 'The Linked List is Empty.'
        if self.last.next==self.last:
            if self.last.data==data:
                self.last=None 
        
        else:
            if self.last.next.data==data:
                self.delete_first()
            else:
                temp=self.last.next
                while temp!=self.last:
                    if temp.next==self.last and temp.next.data==data:
                        self.delete_last()
                        return
                    if temp.next.data==data:
                        temp.next=temp.next.next
                        return
                    temp=temp.next
                return "The specified element doesn't exist in the list"
                
cll1=CLL()
cll1.is_empty()
cll1.insert_at_start(1)
cll1.insert_at_start(2)
cll1.insert_at_start(3)
cll1.insert_at_last(4)
cll1.insert_at_last(5)
cll1.search(2)
cll1.insert_after(1,3)
cll1.search(3)
print(cll1)
for i in cll1:
    print(i)
# cll1.delete_first()
# print(cll1)
# cll1.delete_last()
# print(cll1)
cll1.delete_item(1)
print(cll1)
cll1.delete_item(5)
print(cll1)
cll1.delete_item(3)
print(cll1)
cll1.delete_item(4)
# Out:
# 3 ,2 ,1 ,4 ,5
# 3
# 2
# 1
# 4
# 5
# 3 ,2 ,4 ,5
# 3 ,2 ,4
# 2 ,4
